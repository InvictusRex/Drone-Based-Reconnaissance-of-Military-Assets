# %%
# !pip install -q ultralytics
import ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.9 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.153 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6361.9/8062.4 GB disk)

# %%
import os
os.environ["WANDB_MODE"] = "disabled"

# %%
# !yolo task=detect mode=train model=/kaggle/input/military-assets-surveillance-yolo11m-model/pytorch/11m-80m-43epochs/1/last.pt data="/kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/dataset.yaml" epochs=100 patience=25 imgsz=1024 batch=24 augment=True cache=True half=True lr0=0.005 device=0,1 project=training_iteration_1 name=training_iteration_1 resume=True
# Out:
# Ultralytics 8.3.153 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
#                                                         CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/kaggle/working/training_iteration_1/training_iteration_1/weights/best.pt conf=0.45 source="/kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images" save=True
# Out:
# Ultralytics 8.3.153 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,034,658 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/1141 /kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images/00037.jpg: 704x1024 1 civilian_vehicle, 63.3ms
# image 2/1141 /kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images/00067.jpg: 768x1024 1 civilian_vehicle, 63.9ms
# image 3/1141 /kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images/00092.jpg: 608x1024 1 civilian_vehicle, 59.7ms
# image 4/1141 /kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images/00094.jpg: 640x1024 1 civilian_vehicle, 56.7ms
# image 5/1141 /kaggle/input/military-assets-detection-garuda/Augmented Downsampled Dataset/test/images/00096.jpg: 704x1024 1 civilian_vehicle, 54.9ms
# ...

# %%
# !zip -r iteration_1_results.zip /kaggle/working/runs/detect/predict
# Out:
#   adding: kaggle/working/runs/detect/predict/ (stored 0%)
#   adding: kaggle/working/runs/detect/predict/676.jpg (deflated 3%)
#   adding: kaggle/working/runs/detect/predict/696.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/610.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/426.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/01461.jpg (deflated 0%)
#   adding: kaggle/working/runs/detect/predict/04313.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/predict/420.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/617.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/predict/547.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/predict/1685.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/02250.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/predict/008978.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/predict/008924.jpg (deflated 4%)
# ...

# %%
# !zip -r iteration_1_metrics.zip /kaggle/working/training_iteration_1/training_iteration_1
# Out:
#   adding: kaggle/working/training_iteration_1/training_iteration_1/ (stored 0%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/results.csv (deflated 62%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/train_batch47880.jpg (deflated 8%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch2_labels.jpg (deflated 4%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/val_batch0_labels.jpg (deflated 10%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/PR_curve.png (deflated 9%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/F1_curve.png (deflated 8%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/confusion_matrix_normalized.png (deflated 19%)
#   adding: kaggle/working/training_iteration_1/training_iteration_1/confusion_matrix.png (deflated 19%)
# ...
